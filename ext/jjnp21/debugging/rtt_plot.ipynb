# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f = open('/home/jp/Documents/tmp/debug_results.dump', 'rb')
result = pickle.load(f)
inv = result.invocations

# %%
inv = inv[inv['t_start'] > 1000]
inv
# Out:
#                             t_wait    t_exec  t_start     memory  \
# time
# 2021-11-02 19:06:13.971811     0.0  0.104761  1000.04  104857600
# 2021-11-02 19:06:13.998931     0.0  0.091881  1000.08  104857600
# 2021-11-02 19:06:14.039398     0.0  0.132348  1000.08  419430400
# 2021-11-02 19:06:14.063639     0.0  0.116589  1000.12  104857600
# 2021-11-02 19:06:14.071010     0.0  0.203960  1000.04  419430400
# ...                            ...       ...      ...        ...
# 2021-11-02 19:23:17.754813     0.0  0.207763  2023.72  419430400
# 2021-11-02 19:23:17.761917     0.0  0.294867  2023.64  104857600
# 2021-11-02 19:23:17.782871     0.0  0.115821  2023.84  419430400
# 2021-11-02 19:23:17.805596     0.0  0.138546  2023.84  104857600
# 2021-11-02 19:23:17.820483     0.0  0.033433  2023.96  419430400
#
#                             tx_time_cl_lb  tx_time_lb_fx replica_city  \
# time
# 2021-11-02 19:06:13.971811       0.088025       0.010030       london
# ...

# %%
plt.plot(inv['t_exec'].resample('5s').mean())
plt.show()
